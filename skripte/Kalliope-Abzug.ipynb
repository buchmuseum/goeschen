# %% [markdown]
# # Import der Metadaten zur Göschen-Sammlung aus Kalliope

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup
import xmltodict
from datetime import datetime
import re

# %%
def sru():
    
    base_url = "https://kalliope-verbund.info/sru"
    params = {'recordSchema' : 'mods37',
          'operation': 'searchRetrieve',
          'version': '1.2',
          'maximumRecords': '100',
          'query': "ead.repository.isil=DE-101d",
         }
    r = requests.get(base_url, params=params)
    xml = soup(r.content, features="xml")
    records = xml.find_all('srw:record')
    
    if len(records) < 100:
        # print(r.url)
        return records
    
    else:
        
        num_results = 100
        i = 101
        while num_results == 100:
            
            params.update({'startRecord': i})
            r = requests.get(base_url, params=params)
            xml = soup(r.content, features="xml")
            new_records = xml.find_all('srw:record')
            records+=new_records
            i+=100
            num_results = len(new_records)
            
        return records

# %%
daten = list()
for record in sru():
    # print(xmltodict.parse(record.find('srw_dc:dc').prettify())["srw_dc:dc"])
    
    #try:
        #daten.append(xmltodict.parse(record.find('srw_dc:dc').prettify())["srw_dc:dc"])
    #except:
        #pass
    try:
        daten.append(xmltodict.parse(record.find('mods').prettify())["mods"])
    except:
        pass
        
    # for feld in record.find('srw_dc:dc'):
        # print(feld)

df = pd.DataFrame.from_dict(daten)
df
# Out:
#                           @xmlns                                 @xmlns:xsi  \
# 0     http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 1     http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 2     http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 3     http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 4     http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# ...                          ...                                        ...
# 1185  http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 1186  http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 1187  http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 1188  http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
# 1189  http://www.loc.gov/mods/v3  http://www.w3.org/2001/XMLSchema-instance
#
#                                     @xsi:schemaLocation  \
# 0     http://www.loc.gov/mods/v3 https://www.loc.gov...
# 1     http://www.loc.gov/mods/v3 https://www.loc.gov...
# 2     http://www.loc.gov/mods/v3 https://www.loc.gov...
# 3     http://www.loc.gov/mods/v3 https://www.loc.gov...
# 4     http://www.loc.gov/mods/v3 https://www.loc.gov...
# ...                                                 ...
# 1185  http://www.loc.gov/mods/v3 https://www.loc.gov...
# 1186  http://www.loc.gov/mods/v3 https://www.loc.gov...
# 1187  http://www.loc.gov/mods/v3 https://www.loc.gov...
# 1188  http://www.loc.gov/mods/v3 https://www.loc.gov...
# 1189  http://www.loc.gov/mods/v3 https://www.loc.gov...
#
#                                              identifier  \
# 0     {'@type': 'uri', '#text': 'https://kalliope-ve...
# 1     {'@type': 'uri', '#text': 'https://kalliope-ve...
# 2     {'@type': 'uri', '#text': 'https://kalliope-ve...
# 3     {'@type': 'uri', '#text': 'https://kalliope-ve...
# 4     {'@type': 'uri', '#text': 'https://kalliope-ve...
# ...                                                 ...
# 1185  {'@type': 'uri', '#text': 'https://kalliope-ve...
# 1186  {'@type': 'uri', '#text': 'https://kalliope-ve...
# 1187  {'@type': 'uri', '#text': 'https://kalliope-ve...
# 1188  {'@type': 'uri', '#text': 'https://kalliope-ve...
# 1189  {'@type': 'uri', '#text': 'https://kalliope-ve...
#
#                                              recordInfo  \
# 0     {'recordIdentifier': {'@source': 'DE-611', '#t...
# 1     {'recordIdentifier': {'@source': 'DE-611', '#t...
# 2     {'recordIdentifier': {'@source': 'DE-611', '#t...
# 3     {'recordIdentifier': {'@source': 'DE-611', '#t...
# 4     {'recordIdentifier': {'@source': 'DE-611', '#t...
# ...                                                 ...
# 1185  {'recordIdentifier': {'@source': 'DE-611', '#t...
# 1186  {'recordIdentifier': {'@source': 'DE-611', '#t...
# 1187  {'recordIdentifier': {'@source': 'DE-611', '#t...
# 1188  {'recordIdentifier': {'@source': 'DE-611', '#t...
# 1189  {'recordIdentifier': {'@source': 'DE-611', '#t...
#
#                                             relatedItem  \
# 0     [{'@type': 'host', 'recordInfo': {'recordIdent...
# 1     [{'@type': 'host', 'recordInfo': {'recordIdent...
# 2     [{'@type': 'host', 'recordInfo': {'recordIdent...
# 3     [{'@type': 'host', 'recordInfo': {'recordIdent...
# 4     [{'@type': 'host', 'recordInfo': {'recordIdent...
# ...                                                 ...
# 1185  [{'@type': 'host', 'recordInfo': {'recordIdent...
# 1186  [{'@type': 'host', 'recordInfo': {'recordIdent...
# 1187  [{'@type': 'host', 'recordInfo': {'recordIdent...
# 1188  [{'@type': 'host', 'recordInfo': {'recordIdent...
# 1189  [{'@type': 'host', 'recordInfo': {'recordIdent...
#
#                                typeOfResource  \
# 0     {'@collection': 'yes', '#text': 'text'}
# 1     {'@collection': 'yes', '#text': 'text'}
# 2     {'@collection': 'yes', '#text': 'text'}
# 3     {'@collection': 'yes', '#text': 'text'}
# 4     {'@collection': 'yes', '#text': 'text'}
# ...                                       ...
# 1185  {'@collection': 'yes', '#text': 'text'}
# 1186  {'@collection': 'yes', '#text': 'text'}
# 1187  {'@collection': 'yes', '#text': 'text'}
# 1188  {'@collection': 'yes', '#text': 'text'}
# 1189  {'@collection': 'yes', '#text': 'text'}
#
#                                                    name  \
# 0     [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 1     [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 2     [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 3     [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 4     [{'@authority': 'DE-588', '@authorityURI': 'ht...
# ...                                                 ...
# 1185  [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 1186  [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 1187  [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 1188  [{'@authority': 'DE-588', '@authorityURI': 'ht...
# 1189  [{'@authority': 'DE-588', '@authorityURI': 'ht...
#
#                                                   genre  \
# 0     {'@authority': 'DE-588', '@authorityURI': 'htt...
# 1     {'@authority': 'DE-588', '@authorityURI': 'htt...
# 2     {'@authority': 'DE-588', '@authorityURI': 'htt...
# 3     {'@authority': 'DE-588', '@authorityURI': 'htt...
# 4     {'@authority': 'DE-588', '@authorityURI': 'htt...
# ...                                                 ...
# 1185  {'@authority': 'DE-588', '@authorityURI': 'htt...
# 1186  {'@authority': 'DE-588', '@authorityURI': 'htt...
# 1187  {'@authority': 'DE-588', '@authorityURI': 'htt...
# 1188  {'@authority': 'DE-588', '@authorityURI': 'htt...
# 1189  {'@authority': 'DE-588', '@authorityURI': 'htt...
#
#                                               titleInfo  \
# 0     {'title': 'Brief von Christian Wilhelm Ahlward...
# 1     {'title': 'Brief von Christian Wilhelm Ahlward...
# 2     {'title': 'Brief von Christian Wilhelm Ahlward...
# 3     {'title': 'Brief von Christian Wilhelm Ahlward...
# 4     {'title': 'Brief von Christian Wilhelm Ahlward...
# ...                                                 ...
# 1185  {'title': 'Brief von Johann Isaak von Gerning ...
# 1186  {'title': 'Brief von Johann Isaak von Gerning ...
# 1187  {'title': 'Brief von Johann Isaak von Gerning ...
# 1188  {'title': 'Brief von Johann Isaak von Gerning ...
# 1189  {'title': 'Brief von Johann Isaak von Gerning ...
#
#                                              originInfo  \
# 0     {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 1     {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 2     {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 3     {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 4     {'dateCreated': 'o.D. [27.April o.J. (1809?)]'...
# ...                                                 ...
# 1185  {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 1186  {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 1187  {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 1188  {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
# 1189  {'dateCreated': [{'@encoding': 'w3cdtf', '@key...
#
#                                                language  \
# 0     {'languageTerm': [{'@authority': 'iso639-2b', ...
# 1     {'languageTerm': [{'@authority': 'iso639-2b', ...
# 2     {'languageTerm': [{'@authority': 'iso639-2b', ...
# 3     {'languageTerm': [{'@authority': 'iso639-2b', ...
# 4     {'languageTerm': [{'@authority': 'iso639-2b', ...
# ...                                                 ...
# 1185  {'languageTerm': [{'@authority': 'iso639-2b', ...
# 1186  {'languageTerm': [{'@authority': 'iso639-2b', ...
# 1187  {'languageTerm': [{'@authority': 'iso639-2b', ...
# 1188  {'languageTerm': [{'@authority': 'iso639-2b', ...
# 1189  {'languageTerm': [{'@authority': 'iso639-2b', ...
#
#                                                location  \
# 0     {'shelfLocator': 'Bö-GS/A/Ahlwardt,Ch.W./Brief...
# 1     {'shelfLocator': 'Bö-GS/A/Ahlwardt,Ch.W./Brief...
# 2     {'shelfLocator': 'Bö-GS/A/Ahlwardt,Ch.W./Brief...
# 3     {'shelfLocator': 'Bö-GS/A/Ahlwardt,Ch.W./Brief...
# 4     {'shelfLocator': 'Bö-GS/A/Ahlwardt,Ch.W./Brief...
# ...                                                 ...
# 1185  {'shelfLocator': 'Bö-GS/A/Gerning, J. I./Brief...
# 1186  {'shelfLocator': 'Bö-GS/A/Gerning, J. I./Brief...
# 1187  {'shelfLocator': 'Bö-GS/A/Gerning, J. I./Brief...
# 1188  {'shelfLocator': 'Bö-GS/A/Gerning, J. I./Brief...
# 1189  {'shelfLocator': 'Bö-GS/A/Gerning, J. I./Brief...
#
#                                     physicalDescription  \
# 0                             {'extent': '1 Br., 4 S.'}
# 1                         {'extent': '1 Br., 1 S., 8˚'}
# 2     {'extent': '1 Br., 11 S. (vom Autor durchnumer...
# 3                         {'extent': '1 Br., 1 S., 8˚'}
# 4                             {'extent': '1 Br., 4 S.'}
# ...                                                 ...
# 1185                      {'extent': '1 Br., 3 S., 8˚'}
# 1186  {'extent': '1 Br., 3 S. mit etw. Textverlust, ...
# 1187     {'extent': '1 Br., 3 S. mit etw. Textverlust'}
# 1188  {'extent': '1 Br., 3 S. mit etw. Textverlust. ...
# 1189  {'extent': '1 Br., 3 S. mit Anschrift auf S. 4...
#
#                                                    note abstract
# 0     {'@type': 'systemDetails', '#text': 'Handschri...      NaN
# 1     {'@type': 'systemDetails', '#text': 'Handschri...      NaN
# 2     {'@type': 'systemDetails', '#text': 'Handschri...      NaN
# 3     {'@type': 'systemDetails', '#text': 'Handschri...      NaN
# 4     {'@type': 'systemDetails', '#text': 'Handschri...      NaN
# ...                                                 ...      ...
# 1185  [{'@type': 'encounteredVariantNames', '#text':...      NaN
# 1186  [{'@type': 'encounteredVariantNames', '#text':...      NaN
# 1187  [{'@type': 'encounteredVariantNames', '#text':...      NaN
# 1188  [{'@type': 'encounteredVariantNames', '#text':...      NaN
# 1189  [{'@type': 'encounteredVariantNames', '#text':...      NaN
#
# [1190 rows x 16 columns]

# %%
df.note.value_counts()
# Out:
# {'@type': 'systemDetails', '#text': 'Handschrift'}                                                                                                                            776
# [{'@type': 'encounteredVariantNames', '#text': 'Adr.: Goschen, George Joachim'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                           70
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Houwald, Ernst Christoph von'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                     31
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Stolberg, Christian Graf zu'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                      27
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Schubart, Ludwig Albrecht'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                        27
#                                                                                                                                                                              ...
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Lange, ..., Professor in Bayreuth, Schwellengasse'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                 1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Krause, ..., Staatsbeamter an der Kammer zu Ansbach-Bayreuth'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]      1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Klose, ..., Professor'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                             1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Jordan, ..., Prof. D(oktor?)'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                      1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Rudolphi, Caroline'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                                1
# Name: note, Length: 137, dtype: int64

# %% [markdown]
# # Umwandlung in Pica

# %%
# Die alten SWD-PPNs werden in aktuelle GND-PPNs umgerechnet, betrifft vor allem prüfziffer

def ppn_check(ppn):
    if "-" in ppn:
        counter = 2
        summe = 0
        for ziffer in ppn[:-2][::-1]:
            summe += int(ziffer) * counter
            counter += 1
        pruefziffer = (11 - (summe % 11) ) % 11
        pruefziffer = "X" if pruefziffer == 10 else pruefziffer
          
        return (8 - len(ppn[:-2])) * "0" + ppn[:-2] + str(pruefziffer)
    else:
        return ppn

# %%
role_replace = {
    "cre":"aut",
    "rcp":"rcp",
    "edt":"edt"}

role_text = {
    "cre":"Verfasser",
    "rcp":"Adressat",
    "edt":"Herausgeber"}

find_tq = {
    "a":"1032507942",
    "b":"1032507977",
    "c":"1032507993",
    "d":"1032508027",
    "g":"103250806X"}

def datensatz_schreiben(row):
    # print(row["originInfo"])
    # print(row['identifier']['#text'])
    pica = """0500 Da
0600 yy\n"""
    if type(row["originInfo"]["dateCreated"]) == list:
        pica += f'1100 {row["originInfo"]["dateCreated"][0]["#text"][:4]}\n1110 {row["originInfo"]["dateCreated"][-1]}'

        if len(row["originInfo"]["dateCreated"][0]["#text"]) == 10:
            pica += f'*{row["originInfo"]["dateCreated"][0]["#text"][8:10]}.{row["originInfo"]["dateCreated"][0]["#text"][5:7]}.{row["originInfo"]["dateCreated"][0]["#text"][:4]}'
        pica += '$4ezth\n'

    elif type(row["originInfo"]["dateCreated"]) == str:
        if year := re.search(r"\d{4}\??",row["originInfo"]["dateCreated"]):
            pica += f"1100 [{year[0]}]\n1110 {year.string}$4ezth\n"
        else:
            pica += f"1100 1900$n[nicht nach 1900]\n1110 {row['originInfo']['dateCreated']}\n"
            # alle Datensätze, die so mangelhafte Datumsinformationen haben, werden in eine Liste geschrieben, damit CS diese nachrecherchieren kann.
            with open("../dat/od-fehlerliste.txt", 'a') as file:
                file.write(f"{row['location']['shelfLocator']}, {row['originInfo']['dateCreated']}\n")
    pica += f"""1130 TB-papier
1130 !040445224!
1131 !040082407!
1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
1500 /1{row['language']['languageTerm'][0]['#text']}
"""
    personcount = 0
    if type(row['name']) == list:
        for person in row['name']:
            if type(person['role']['roleTerm']) == list:
                pica += f"30{personcount}0 !{person['@valueURI'].split('/')[-1]}!$B{role_text[person['role']['roleTerm'][0]['#text']]}$4{role_replace[person['role']['roleTerm'][0]['#text']]}\n"
            elif type(person['role']['roleTerm']) == dict:
                if person['role']['roleTerm']['#text'] == "Schreiber":
                    pass
                elif person['role']['roleTerm']['#text'] == "Korrespondenzpartner":
                    pica += f"30{personcount}0 !{person['@valueURI'].split('/')[-1]}!$BKorrespondenzpartner$4krp\n"
                else:
                    pica += f"30{personcount}0 !{person['@valueURI'].split('/')[-1]}!$B{person['role']['roleTerm']['#text']}$4oth\n"
            personcount += 1
    
    elif type(row['name']) == dict:
        pica += f"3000 !{row['name']['@valueURI'].split('/')[-1]}!$B{role_text[row['name']['role']['roleTerm'][0]['#text']]}$4{role_replace[row['name']['role']['roleTerm'][0]['#text']]}\n"
    pica += f"""4000 {row['titleInfo']['title']}
"""
    if row['originInfo']['place']['placeTerm']['#text'].lower() == "o.o.":
        pica += "4046 [Entstehungsort nicht ermittelbar]\n"
    else:
        pica += f"4046 {row['originInfo']['place']['placeTerm']['#text']}\n"
    
    pica += f"""4060 {row['physicalDescription']['extent']}
4105 !1059146037!
4105 !1077661932!
"""
    if type(row['note']) == dict:
        if row['note']['@type'] == 'encounteredVariantNames':
            pica += f"4201 alternative Namensform {row['note']['#text']}\n"
    elif type(row['note']) == list:
        for note in row['note']:
            if type(note) == dict:
                if note['@type'] == 'encounteredVariantNames':
                    pica += f"4201 alternative Namensform {note['#text']}\n"
    
    pica += "4700 |BSM|\n"

    if type(row['abstract']) != float:
        pica += f"4705 {row['abstract']['#text']}\n"
    
    pica += """5560 [RNA]Korrespondenz
5590 [Objektgattung]
5590 !040082407!
"""
    if len(row['originInfo']['place']['placeTerm']) > 2:
        pica += f"5591 [Entstehungsort]\n5591 !{ppn_check(row['originInfo']['place']['placeTerm']['@valueURI'].split('/')[-1])}!\n"
    pica += f"""7001 {now.strftime('%d-%m-%y')} : x
4800 !009033645!
6710 !{find_tq[row['location']['shelfLocator'].split('/',1)[1][:1].lower()]}!
7100 {row['location']['shelfLocator']} @ m
7109 !!DBSM/S!! ; {row['location']['shelfLocator']}"""
    pica += "\n\t\n"
    
    return pica

# %%
df.note.value_counts()
# Out:
# {'@type': 'systemDetails', '#text': 'Handschrift'}                                                                                                                            776
# [{'@type': 'encounteredVariantNames', '#text': 'Adr.: Goschen, George Joachim'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                           70
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Houwald, Ernst Christoph von'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                     31
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Stolberg, Christian Graf zu'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                      27
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Schubart, Ludwig Albrecht'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                        27
#                                                                                                                                                                              ...
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Lange, ..., Professor in Bayreuth, Schwellengasse'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                 1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Krause, ..., Staatsbeamter an der Kammer zu Ansbach-Bayreuth'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]      1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Klose, ..., Professor'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                             1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Jordan, ..., Prof. D(oktor?)'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                      1
# [{'@type': 'encounteredVariantNames', '#text': 'Verf.: Rudolphi, Caroline'}, {'@type': 'systemDetails', '#text': 'Handschrift'}]                                                1
# Name: note, Length: 137, dtype: int64

# %%
now = datetime.now()
for index, row in df.sample(5).iterrows():
    print(datensatz_schreiben(row))
# Out:
# 0500 Da
# 0600 yy
# 1100 1785
# 1110 22.02.1785*22.02.1785$4ezth
# 1130 TB-papier
# 1130 !040445224!
# 1131 !040082407!
# 1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
# 1500 /1ger
# 3000 !118554077!$BVerfasser$4aut
# 3010 !118695916!$BAdressat$4rcp
# 4000 Brief von Ludwig Ferdinand Huber an Georg Joachim Göschen
# 4046 Leipzig
# 4060 1 Br., 1 S. mit Anschrift auf S. 4, 8˚
# 4105 !1059146037!
# 4105 !1077661932!4700 |BSM|
# 5560 [RNA]Korrespondenz
# 5590 [Objektgattung]
# 5590 !040082407!
# 5591 [Entstehungsort]
# 5591 !040352064!
# 7001 02-09-22 : x
# 4800 !009033645!
# 6710 !1032507942!
# 7100 Bö-GS/A/Huber, L. F./Brief 1, Kasten 7 @ m
# 7109 !!DBSM/S!! ; Bö-GS/A/Huber, L. F./Brief 1, Kasten 7
#
#
# 0500 Da
# 0600 yy
# 1100 1805
# 1110 13.03.1805-08.12.1805*13.03.1805$4ezth
# 1130 TB-papier
# 1130 !040445224!
# 1131 !040082407!
# 1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
# 1500 /1ger
# 3000 !118695916!$BKorrespondenzpartner$4krp
# 3010 !118824775!$BKorrespondenzpartner$4krp
# 4000 Korrespondenz zwischen Georg Joachim Göschen und Carl August Böttiger
# 4046 [Entstehungsort nicht ermittelbar]
# 4060 Briefe, 41 Blätter im Umschlag, 8˚
# 4105 !1059146037!
# 4105 !1077661932!4201 alternative Namensform 2.Korr.: Böttiger, Karl August
# 4700 |BSM|
# 5560 [RNA]Korrespondenz
# 5590 [Objektgattung]
# 5590 !040082407!
# 7001 02-09-22 : x
# 4800 !009033645!
# 6710 !1032507977!
# 7100 Bö-GS/B/Böttiger, K. A., Kasten 1-2, Mappe 1 @ m
# 7109 !!DBSM/S!! ; Bö-GS/B/Böttiger, K. A., Kasten 1-2, Mappe 1
#
#
# 0500 Da
# 0600 yy
# 1100 1789
# 1110 16.10.1789*16.10.1789$4ezth
# 1130 TB-papier
# 1130 !040445224!
# 1131 !040082407!
# 1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
# 1500 /1ger
# 3000 !118554077!$BVerfasser$4aut
# 3010 !118695916!$BAdressat$4rcp
# 4000 Brief von Ludwig Ferdinand Huber an Georg Joachim Göschen
# 4046 Mainz
# 4060 1 Br.
# 4105 !1059146037!
# 4105 !1077661932!4700 |BSM|
# 4705 Das Stück kursiert auf den Bühnen; Mitarbeit an der "Thalia" und "Musäum"
# 5560 [RNA]Korrespondenz
# 5590 [Objektgattung]
# 5590 !040082407!
# 5591 [Entstehungsort]
# 5591 !040371247!
# 7001 02-09-22 : x
# 4800 !009033645!
# 6710 !1032507993!
# 7100 Bö-GS/C/Huber, L. F./Brief 4 @ m
# 7109 !!DBSM/S!! ; Bö-GS/C/Huber, L. F./Brief 4
#
#
# 0500 Da
# 0600 yy
# 1100 1790
# 1110 01.07.1790 [oder danach, notiert von anderer Hand]*01.07.1790$4ezth
# 1130 TB-papier
# 1130 !040445224!
# 1131 !040082407!
# 1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
# 1500 /1ger
# 3000 !118661078!$BVerfasser$4aut
# 3010 !118695916!$BAdressat$4rcp
# 4000 Brief von Heinrich Christian Boie an Georg Joachim Göschen
# 4046 Meldorf
# 4060 1 Br., 4 S. (Verlagsvertrag zum "Neuen Dt. Museum")
# 4105 !1059146037!
# 4105 !1077661932!4700 |BSM|
# 5560 [RNA]Korrespondenz
# 5590 [Objektgattung]
# 5590 !040082407!
# 7001 02-09-22 : x
# 4800 !009033645!
# 6710 !1032507942!
# 7100 Bö-GS/A/Boie, H. Ch./Brief 20, Kasten 3 @ m
# 7109 !!DBSM/S!! ; Bö-GS/A/Boie, H. Ch./Brief 20, Kasten 3
#
#
# 0500 Da
# 0600 yy
# 1100 1789
# 1110 04.04.1789*04.04.1789$4ezth
# 1130 TB-papier
# 1130 !040445224!
# 1131 !040082407!
# 1132 a1-analog;a2-hand;f1-text;f2-blatt;e2-uv;o-org;v-ganz
# 1500 /1ger
# 3000 !118554514!$BVerfasser$4aut
# 3010 !118695916!$BAdressat$4rcp
# 4000 Brief von Christoph Wilhelm von Hufeland an Georg Joachim Göschen
# 4046 Weimar
# 4060 1 Br., 3 S. mit Anschrift auf S. 4, mit etw. Textverlust, 8˚
# 4105 !1059146037!
# 4105 !1077661932!4700 |BSM|
# 5560 [RNA]Korrespondenz
# 5590 [Objektgattung]
# 5590 !040082407!
# 5591 [Entstehungsort]
# 5591 !040651053!
# 7001 02-09-22 : x
# 4800 !009033645!
# 6710 !1032507942!
# 7100 Bö-GS/A/Hufeland, Ch. W./Brief 1, Kasten 7 @ m
# 7109 !!DBSM/S!! ; Bö-GS/A/Hufeland, Ch. W./Brief 1, Kasten 7

# %%
now = datetime.now()
with open(f"../dat/goeschen-{now.strftime('%y-%m-%d-%H-%M-%S')}.dat","w") as f:
    with open(f"../dat/goeschen-recent.dat", 'w') as f2:
        for index, row in df.iterrows():
            f.write(datensatz_schreiben(row))
            f2.write(datensatz_schreiben(row))

with open(f"../dat/goeschen-recent-sample.dat", 'w') as f:
    for index, row in df.sample(5).iterrows():
        f.write(datensatz_schreiben(row))
